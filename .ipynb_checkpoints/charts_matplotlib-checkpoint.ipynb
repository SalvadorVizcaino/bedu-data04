# %%
# %matplotlib inline # Solo como referencia para en dado caso que no me desplieque la grafica jupyter
import matplotlib.pyplot as plt

plt.plot([1, 3, 5, 23, 12])

# %%
plt.plot([1, 3, 5, 23, 12], linewidth=4)

# %%
values_in_x = [120, 89, 56, 172, 12, 129]
values_in_y = ['Nuevo Leon', 'CDMX', 'Jalisco', 'Culiacan', 'Puebla', 'Guerrero']

# %%
plt.bar(values_in_y, values_in_x)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.scatter(values_in_y, values_in_x)
plt.title("holis")
plt.xlabel("x-label")
plt.ylabel("y-label")
# Out:
# Text(0, 0.5, 'y-label')
