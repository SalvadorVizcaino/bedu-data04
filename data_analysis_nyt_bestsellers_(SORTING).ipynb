# %%
# Importing data
import pandas as pd

# Dataframe preparation
FILENAME = 'datasets/new_york_times_bestsellers.csv'

# Data Frame reading
df = pd.read_csv(FILENAME)
df.head()
# Out:
#    Unnamed: 0                                 amazon_product_url  \
# 0           0  http://www.amazon.com/The-Host-Novel-Stephenie...
# 1           1  http://www.amazon.com/Love-Youre-With-Emily-Gi...
# 2           2  http://www.amazon.com/The-Front-Garano-Patrici...
# 3           3  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# 4           5  http://www.amazon.com/Phantom-Prey-John-Sandfo...
#
#               author                                        description  \
# 0    Stephenie Meyer  Descr: Aliens have taken control of the minds ...
# 1       Emily Giffin  Descr: A woman's happy marriage is shaken when...
# 2  Patricia Cornwell  Descr: A Massachusetts state investigator and ...
# 3    Chuck Palahniuk  Descr: An aging porn queens aims to cap her ca...
# 4      John Sandford  Descr: The Minneapolis detective Lucas Davenpo...
#
#        publisher                     title                       oid  \
# ...

# %%
df.sort_values('price.numberDouble', ascending=False).head()
# Out:
#       Unnamed: 0                                 amazon_product_url  \
# 1727        2264  http://www.amazon.com/1Q84-Haruki-Murakami-ebo...
# 1719        2255  http://www.amazon.com/1Q84-Haruki-Murakami-ebo...
# 1735        2276  http://www.amazon.com/1Q84-Haruki-Murakami-ebo...
# 1744        2287  http://www.amazon.com/1Q84-Haruki-Murakami-ebo...
# 1703        2232  http://www.amazon.com/1Q84-Haruki-Murakami-ebo...
#
#                author                                        description  \
# 1727  Haruki Murakami  Descr: In 1980s Tokyo, a woman who punishes pe...
# 1719  Haruki Murakami  Descr: In 1980s Tokyo, a woman who punishes pe...
# 1735  Haruki Murakami  Descr: In 1980s Tokyo, a woman who punishes pe...
# 1744  Haruki Murakami  Descr: In 1980s Tokyo, a woman who punishes pe...
# 1703  Haruki Murakami  Descr: In 1980s Tokyo, a woman who punishes pe...
#
#      publisher title                       oid bestsellers_date.numberLong  \
# ...

# %%
df['published_date.numberLong'] = pd.to_datetime(df['published_date.numberLong'], unit="ms")

# %%
df.sort_values('published_date.numberLong', ascending=True).head()
# Out:
#    Unnamed: 0                                 amazon_product_url  \
# 0           0  http://www.amazon.com/The-Host-Novel-Stephenie...
# 1           1  http://www.amazon.com/Love-Youre-With-Emily-Gi...
# 2           2  http://www.amazon.com/The-Front-Garano-Patrici...
# 3           3  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# 4           5  http://www.amazon.com/Phantom-Prey-John-Sandfo...
#
#               author                                        description  \
# 0    Stephenie Meyer  Descr: Aliens have taken control of the minds ...
# 1       Emily Giffin  Descr: A woman's happy marriage is shaken when...
# 2  Patricia Cornwell  Descr: A Massachusetts state investigator and ...
# 3    Chuck Palahniuk  Descr: An aging porn queens aims to cap her ca...
# 4      John Sandford  Descr: The Minneapolis detective Lucas Davenpo...
#
#        publisher                     title                       oid  \
# ...

# %%
df['publisher'].value_counts()
# Out:
# Putnam                267
# Grand Central         227
# Knopf                 216
# Little, Brown         211
# Doubleday             153
#                      ...
# Viking,                 1
# Ecco/HarperCollins      1
# Daw                     1
# Twelve                  1
# Tor/ Tom Doherty        1
# Name: publisher, Length: 69, dtype: int64

# %%
df_little_brown = df[df['publisher'] == 'Little, Brown']

# %%
df_little_brown.sort_values('price.numberDouble', ascending=False).head()
# Out:
#       Unnamed: 0                                 amazon_product_url  \
# 1706        2236  http://www.amazon.com/Kill-Alex-Cross-James-Pa...
# 2135        2841  http://www.amazon.com/Merry-Christmas-Cross-Ja...
# 1714        2247  http://www.amazon.com/Kill-Alex-Cross-James-Pa...
# 1723        2259  http://www.amazon.com/Kill-Alex-Cross-James-Pa...
# 1730        2270  http://www.amazon.com/Kill-Alex-Cross-James-Pa...
#
#                author                                        description  \
# 1706  James Patterson  Descr: Alex Cross investigates when the presid...
# 2135  James Patterson  Descr: Detective Alex Cross confronts both a h...
# 1714  James Patterson  Descr: Alex Cross investigates when the presid...
# 1723  James Patterson  Descr: Alex Cross investigates when the presid...
# 1730  James Patterson  Descr: Alex Cross investigates when the presid...
#
#           publisher                        title                       oid  \
# ...

# %%
df_little_brown.sort_values('weeks_on_list.numberInt', ascending=False).head()
# Out:
#      Unnamed: 0                                 amazon_product_url  \
# 583         773  http://www.amazon.com/The-Host-Novel-Stephenie...
# 536         710  http://www.amazon.com/The-Host-Novel-Stephenie...
# 518         683  http://www.amazon.com/The-Host-Novel-Stephenie...
# 510         670  http://www.amazon.com/The-Host-Novel-Stephenie...
# 500         655  http://www.amazon.com/The-Host-Novel-Stephenie...
#
#               author                                        description  \
# 583  Stephenie Meyer  Descr: Aliens have taken control of the minds ...
# 536  Stephenie Meyer  Descr: Aliens have taken control of the minds ...
# 518  Stephenie Meyer  Descr: Aliens have taken control of the minds ...
# 510  Stephenie Meyer  Descr: Aliens have taken control of the minds ...
# 500  Stephenie Meyer  Descr: Aliens have taken control of the minds ...
#
#          publisher     title                       oid  \
# 583  Little, Brown  THE HOST  5b4aa4ead3089013507db66e
# ...
